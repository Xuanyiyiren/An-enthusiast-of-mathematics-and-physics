# %% [markdown]
# <a href="https://colab.research.google.com/github/Xuanyiyiren/An-enthusiast-of-mathematics-and-physics/blob/main/LatexOCR_correction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install openai --quite
# Out:
# Collecting openai
#   Downloading openai-1.45.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.9.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.8)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.23.3)
# Downloading openai-1.45.0-py3-none-any.whl (374 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.1/374.1 kB 19.5 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.7 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.1 MB/s eta 0:00:00
# Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 25.0 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.1 MB/s eta 0:00:00
# Installing collected packages: jiter, h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 jiter-0.5.0 openai-1.45.0

# %%
from openai import OpenAI
from google.colab import userdata
import os
import re

class AI_latexCode_correction:
    def __init__(self, max_tokens=1000):
        self.max_tokens = max_tokens
        self.Sys_prompt = """\
        你将接收到一些经过 LaTeXOCR 得到的 LaTeX 源代码，请你帮忙检查并修正其中的语法错误、OCR产生的错别字等问题。同时请注意调整以下内容
        1. 将所有的行间公式调整为有编号的行间公式，即\begin{equation}...\end{equation}，其中不带有*
        2. 将所有的小标题 section,subsection,subsubsection 调整为有编号的，即去掉原代码中的*和手动编号
        3. 将所有的图片或表格调整为有编号的，即\begin{figure}...\end{figure} ，即去掉原代码中的*
        """
        self.file_path = ""
        self.content = ""
        self.modified_content = ""
        self._dollar_begin = True

    # First Part: get the latex codes
    def get_files_and_set_path(self,directory = "./"):
        """
        This method will scan and extract all the .tex files in the directory and return the list, which is sorted by modify time.
        Meanwhile, it also set the attribution self.file_path for the newest .tex file.
        """
        files = [f for f in os.listdir(directory)\
                if os.path.isfile(os.path.join(directory, f)) and os.path.splitext(f)[1] ==".tex"]

        sorted_files = files.sort(key=lambda x: os.path.getmtime(x))
        self.file_path = directory + files[0]
        print("Get content automatically.")
        return files

    def get_content(self):
        """
        This method will get the content from self.file_path.
        The content will be returned and stored in self.content.
        If self.file_path is empty, it will run self.get_files_and_set_path to set self.file_path.
        """
        if not self.file_path:
            self.get_files_and_set_path()
        with open(self.file_path, 'r') as file:
            content = file.read()
        self.content = content
        return content

    # Second Part: split the codes into chunks according to the max token
    # Here is some difficulty:
    # 1. Split in to different parts and keep the most basic semantics and grammer of latex codes
    # 2. How to calculate the token for a text.
    def _is_start_tag(self, line):
        if line[:len(r"$$")] == r"$$" and self._dollar_begin:
            self._dollar_begin = False
            return (True,"$$")
        if line[:len(r"\[")] == r"\[":
            return (True, "[]")
        if line[:len(r"\begin{")] == r"\begin{":
            if line[len(r"\begin{"):len(r"\begin{document}")] != r"document}":
                return (True, "be")
        return False,None
    def _is_end_tag(self, line):
        if line[:len(r"$$")] == r"$$" and not self._dollar_begin:
            self._dollar_begin = True
            return (True,"$$")
        if line[:len(r"\]")] == r"\]":
            return (True, "[]")
        if line[:len(r"\end{")] == r"\end{":
            if line[len(r"\end{"):len(r"\end{document}")] != r"document}":
                return (True, "be")
        return False,None

    def _pre_split(self):
        """
        This method will split the content into some indivisible parts.
        indivisible means a text lines or something like "begin{...} ... end{...}",
        while begin{document} will be ignored.
        """
        # print(self.content)
        if not self.content:
            self.get_content()
        self._dollar_begin = True
        lines = (self.content).splitlines(keepends=True)
        basic_parts = []
        stack = []
        for index, line in enumerate(lines):
            is_start, start_flag = self._is_start_tag(line)
            is_end, end_flag = self._is_end_tag(line)
            if is_start:
                if not stack:
                    start_pos = index
                stack.append(start_flag)

            elif is_end:
                if stack:
                    if stack[-1] == end_flag:
                        stack.pop()
                        if not stack:
                            end_pos = index + 1
                            basic_parts.append("".join(lines[start_pos:end_pos]))
                    else:
                        raise LatexError("Not Match!")
                else:
                    raise LatexError("Not Match!")
            else:
                if not stack:
                    basic_parts.append(line)
        return basic_parts

    token_counter_map = {
        "ave": "token_counter_average",
    }
    chinese_punctuations = "，。！？；：、“”‘’（）《》【】"

    @staticmethod
    def _count_chars(text):
        chinese_count = 0
        english_count = 0
        chinese_punctuation_count = 0
        english_punctuation_count = 0

        for char in text:
            if char in [' ', '\n']:
                continue
            if '\u4e00' <= char <= '\u9fff':
                chinese_count += 1
            elif 'a' <= char <= 'z' or 'A' <= char <= 'Z':
                english_count += 1
            else:
                if char in AI_latexCode_correction.chinese_punctuations:
                    chinese_punctuation_count += 1
                else:
                    english_punctuation_count += 1

        total_count = len(text)

        return (chinese_count + chinese_punctuation_count,
                english_count + english_punctuation_count)
    @staticmethod
    def token_counter_average(text: str) -> int:
        """
        Through `https://platform.deepseek.com/api-docs/guides/token_usage/`
        """
        chinese_count, english_count = AI_latexCode_correction._count_chars(text)
        return chinese_count * 0.6 + english_count * 0.3

    def split_into_chunks(self, count_mode="ave"):
        token_counter = getattr(self, self.token_counter_map.get(count_mode))
        if not token_counter:
            raise ValueError(f"Invalid count_mode: {count_mode}")

        sentences = self._pre_split()

        # 初始化段落列表和当前段落
        chunks = []
        current_chunk = ""
        current_token_count = 0

        for sentence in sentences:
            # display(sentence)
            new_token_count = token_counter(sentence)

            # 如果当前段落加上新句子超过最大token数，则保存当前段落并开始新段落
            if current_token_count + new_token_count > self.max_tokens:
                if current_chunk:
                    chunks.append(current_chunk)
                current_chunk = sentence
                current_token_count = new_token_count
            else:
                # 否则，将句子添加到当前段落
                current_chunk += sentence
                current_token_count += new_token_count

        # 添加最后一个段落
        if current_chunk:
            chunks.append(current_chunk)

        return chunks


    # Part 3:
    # This part we use LLM to correct the latex codes chunk by chunk.

    def LLMmodel_Deepseek(self, Usr_prompt):
        """
        This method use deepseek-coder model. The system prompt is set in __init__, and the user's prompt is set in argument.
        The system prompt is asking the LLM to check and correct errors in the original latex codes.
        We extract the code part in the answer of the LLM.
        """
        client = OpenAI(api_key=userdata.get('DEEPSEEK_API_KEY'), base_url="https://api.deepseek.com")
        response = client.chat.completions.create(
            model="deepseek-coder",
            messages=[
                {"role": "system", "content": self.Sys_prompt},
                {"role": "user", "content": Usr_prompt},
            ],
            stream=False
        )
        pattern = r"```(.*?)```"
        matches = re.findall(pattern, response.choices[0].message.content, re.DOTALL)
        return matches[0]

    def recombination(self):
        modified_chunks = []
        chunks = self.split_into_chunks()
        for chunk in chunks:
            modified_chunk = self.LLMmodel_Deepseek(chunk)
            modified_chunks.append(modified_chunk)
        self.modified_content = "".join(modified_chunks)
        return self.modified_content

# %%
# testing code
test = AI_latexCode_correction(max_tokens= 500)
print("Getting files and contents ...")
test.get_content()
print("Getting contents successfully, the content is: ")
print('-'*30)
print(test.content)
print('-'*30)
print("Splitting into chunks ...")
chunks = test.split_into_chunks()
print("Splitting successfully, the chunks are: ")
print('='*30)
for index, chunk in enumerate(chunks):
    print(f"The #{index + 1} chunks:")
    print('-'*20)
    print(chunk)
    print('-'*20)
print('='*30)
print("Using LLM correcting ...")
test.recombination()
print("Correction successfully, the modified content is: ")
print('-'*30)
print(test.modified_content)
print('-'*30)
# Out:
# Getting files and contents ...
# Get content automatically.
# Getting contents successfully, the content is:
# ------------------------------
# % This LaTeX document needs to be compiled with XeLaTeX.
# \documentclass[10pt]{article}
# \usepackage[utf8]{inputenc}
# \usepackage{ucharclasses}
# \usepackage{amsmath}
# \usepackage{amsfonts}
# \usepackage{amssymb}
# \usepackage[version=4]{mhchem}
# \usepackage{stmaryrd}
# \usepackage{graphicx}
# \usepackage[export]{adjustbox}
# \graphicspath{ {./images/} }
# \usepackage{multirow}
# \usepackage[fallback]{xeCJK}
# \usepackage{polyglossia}
# \usepackage{fontspec}
# \setCJKmainfont{Noto Serif CJK SC}
#
# \setmainlanguage{english}
# \setotherlanguages{hindi}
# \newfontfamily\hindifont{Noto Serif Devanagari}
# \newfontfamily\lgcfont{CMU Serif}
# \setDefaultTransitions{\lgcfont}{}
# \setTransitionsFor{Hindi}{\hindifont}{\lgcfont}
#
# \title{使用离子流计算分压力的方法: }
#
# \author{}
# \date{}
#
#
# \begin{document}
# \maketitle
# 实验内容:
#
# \begin{enumerate}
#   \item 使用法拉第筒收集缡子流，以分压力为纵坐标测三个谱
#   \item 将上达测得的一个谱转化成以离子流为纵坐标, 并用离子流求出残余气体 $\left(\mathrm{H}_{2}, \mathrm{He}^{2}, \mathrm{CH}_{4}, \mathrm{H}_{2} \mathrm{O}, \mathrm{N}_{2}, \mathrm{CO}, \mathrm{O}_{2}, \mathrm{Ar}\right.$ 和 $\left.\mathrm{CO}_{2}\right)$ 的分压, 再与以分压力为纵坐标的橧进行比较, 分析造成两者差距的原因 (残余气体分压的计算结果需要写进实验报告)。
# \end{enumerate}
#
# 在用残余气体分析仪(RGA) 分析真空系统中的残余气体成分时，为了计算出主要的几种残余气体的分压，需要分析清楚所观察到的谱峰与残余气体之间的关系。由于残余气体是混合气体，在谱图中，除了有相应于一次电离分子的主峰外, 还存在着一些副峰, 这些副峰主要来源于气体电离时形成的碎片离子、多电荷离子及同位素杂质。某一种组分气体电离所得到的各个峰的丰度仅取决于该组分气体的碎片图形，而与所分析的混合气体中存在的其它组分气体无关。在分析不同组分气体对谱图中某一个峰的贡献时可以采用线性叠加的方法, 在此基础上可以求得组分气体的分压。
#
# \section*{1. 峰与残余气体分压的关系}
# 对于 RGA 扫描出的某个峰 $a$ 来说. 其离子流的值 $I_{a}$ 可能是多种组分气体贡献的迭加, 即:
#
#
# \begin{equation*}
# I_{a}=\sum_{i} I_{i a} \tag{1}
# \end{equation*}
#
#
# 式中， $I_{I a}$ 是第 $i$ 种气体的全离子流 $I$ 中被 RGA 检测到的质荷比为 $a$ 的离子流的值, $I_{w}$ 与 $I$ 的关系是:
#
#
# \begin{equation*}
# I_{i a}=T_{a} \bullet F_{i a} \bullet I_{i} \tag{2}
# \end{equation*}
#
#
# 式中 $F_{i a}$ 是第 $i$ 中气体的全离子流中质荷比为 $a$ 的离子流所占的丰度, $T_{a}$ 是 RGA 对质何比为 $a$ 的离子流的传输几率。假设第 $i$ 种气体的分压为 $p_{1}, \mathrm{RGA}$ 住使用法拉第筒的情况下， $l_{1}$ 对 $p$ 的灵敏度（也就是第 $i$ 种气体的灵敏度）为 $s_{1}$ ，那么, $p$ ，和 $I$ ，有以下关系：
#
#
# \begin{equation*}
# I_{i}=s_{i} \cdot p_{i} \tag{3}
# \end{equation*}
#
#
# 不同气体之所以会有不同的灵敏度，主要是因为它们的电离茷面不同。杲种气体(设为第 $i$ 种气(体)相对于钻气气的相对电离截面 $\sigma_{1}$ 一般是稳定的常数, 那么,
#
# \begin{center}
# \includegraphics[max width=\textwidth]{2024_09_13_8a2ddce69efcfc4d9ac9g-2}
# \end{center}
#
#
# \begin{equation*}
# s_{1}=\sigma_{1} \bullet s_{N_{2}} \tag{4}
# \end{equation*}
#
#
# 通常RGA的说明书里不会给出每种气体的全离子流对该气体的灵敏度，而是给出在法拉第简的情况下 $\left.1^{14} \mathrm{~N}_{2}\right]^{+}$(质荷比为 28 ) 离了流对氮气的灵敏度 $s$ 作为 RGA的标称灵敏度。注意， $s$ 并不是氮气的灵敏度！
#
# 得气的灵敏度 $s_{\mathrm{V}}$, 与RGA的标称灵敏度 $s$ 有如下关系:
#
#
# \begin{equation*}
# s=T_{28} \bullet F_{\left.N_{2} \mid 28\right]} \bullet s_{N_{2}} \tag{5}
# \end{equation*}
#
#
# 式中 $F_{\mathrm{N},[28]}$ 是氮气的全离子流中 $\left[{ }^{14} \mathrm{~N}_{2}\right]^{+}$的丰度， $T_{28}$ 是质谱计对质荷比为 28 的离子流的传输几率。
#
# 由式（1）－（5）可以得出RGA扫描出的某个峰 $a$ 与对它有贡献的各残余气体分压的关系为:
#
#
# \begin{equation*}
# I_{a}=\sum_{1} \frac{p_{1} \bullet s \bullet \sigma_{1} \bullet T_{a} \bullet F_{\text {Ia }}}{T_{28} \bullet F_{N_{2}[28]}} \tag{6}
# \end{equation*}
#
#
# 注意到某些峰只来源于单一气体, 比如[2]峰只来源于 $\mathrm{H}_{2}$, [4]峰只来源于 He ,那么对于这样的峰,式(6)中的求和符号可以去掉, 根据 $I_{2}$ 可以直接计算 $p_{H_{2}}$, 根据 $I_{4}$可以直接计算 $p_{\text {Hic }}$ 。如果某个峰不是来源于单一气体，比如[28]可能来自 $\mathrm{N}_{2}$ 和 CO , 那么可以选择与 $\mathrm{N}_{2}$ 和 CO 相关的副峰[14]来参与计算, 通过解方程组求得 $\mathrm{N}_{2}$ 和 CO 的分压。
#
# \section*{2. 系数的确定}
# 在超高真空系统中,残余气体的主要包括 $\mathrm{H}_{2}, \mathrm{He}^{2}, \mathrm{CH}_{4}, \mathrm{H}_{2} \mathrm{O}, \mathrm{N}_{2}, \mathrm{CO}, \mathrm{O}_{2}, \mathrm{Ar}$ 和 $\mathrm{CO}_{2}$这些气体，它们的离子的质荷比都在 50 以内。
#
# 常见气体的相对电离截面 $\sigma_{i}$ 可以从下表中计算得出。
#
# \includegraphics[max width=\textwidth, center]{2024_09_13_8a2ddce69efcfc4d9ac9g-3(1)}\\
# $T_{\rho} / T_{28}$ 是质哬比为 $a$ 的离子流的相对传输几率 (相对 $\left[^{[4} \mathrm{N}_{2}\right]^{+}$), 通常有如下关系:
#
#
# \begin{equation*}
# \frac{T_{a}}{T_{28}}=\frac{28}{a} \tag{7}
# \end{equation*}
#
#
# $F_{i u}$ 和 $F_{N, 128]}$ 可以查气体的碎片图形表. 有衣中的相对丰度（主峰为 $100 \%$ ）米计算丰度如表2。
#
# 表2 常见残余气体果暨床不比䁖的丰度
#
# \begin{center}
# \begin{tabular}{|c|c|c|}
# \hline
# ${ }^{2}$ (14 & \includegraphics[max width=\textwidth]{2024_09_13_8a2ddce69efcfc4d9ac9g-3}
#  & 112 \\
# \hline
# \multirow{2}{*}{$\mathrm{N}_{2}$} & 28 & 0.94366 \\
# \hline
#  & 14 & 0. 0490705 \\
# \hline
# $\mathrm{H}_{2}$ & 2 & 0.97943 \\
# \hline
# He & 4 & 1 \\
# \hline
# \multirow{2}{*}{$\mathrm{CH}_{4}$} & 15 & 0. 40168 \\
# \hline
#  & 14 & 0.0747314 \\
# \hline
# $\mathrm{H}_{2} \mathrm{O}$ & 18 & $0.76 \times 05$ \\
# \hline
# \multirow{2}{*}{co} & 28 & 0.92166 \\
# \hline
#  & 14 & 0. 0064516 \\
# \hline
# $\mathrm{O}_{2}$ & 32 & 0.92098 \\
# \hline
# Ar & 40 & 0. $8 \times 1 \times 3$ \\
# \hline
# \multirow{2}{*}{$\mathrm{CO}_{2}$} & 44 & 0.76570 \\
# \hline
#  & 28 & 0.068913 \\
# \hline
# \end{tabular}
# \end{center}
#
# 本实验中所用的RGA的标称灵敏度 $s=1.36 \times 10^{-1}$
#
# \section*{3. 分压的计算}
# 要求：选取质荷比分别为 $2,4,15,18,32,40,44$ 的 7 个峰（可以认为这些峰来自于单一气体）的离子流值来分别计算 $\mathrm{H}_{2}, \mathrm{He}^{-}, \mathrm{CH}_{4}, \mathrm{H}_{2} \mathrm{O}, \mathrm{O}_{2}, \mathrm{Ar}$ 和 $\mathrm{CO}_{2}$ 的分
#
# \section*{压。选取荷质比为 14 和 28 的峰的离子流来计算 $\mathrm{N}_{2}$ 和 CO 分压（需要列方程组求解)。}
# \section*{4. 附表(真空设计手册第十二章 第七节]}
# 由下面的表12-9至表12-11可以求出某种气体碎裂后, 不同质荷比的离子的丰度。以 N 2 的 $\left[{ }^{14} \mathrm{~N}_{2}\right]^{+}$的丰度为例:
#
# $$
# F_{N_{2}[28]}=\frac{100}{100+5.2+0.8+0.01}=0.94331
# $$
#
# 与表2中的 0.94366 比较接近。
#
# \begin{center}
# \begin{tabular}{|c|c|c|c|c|c|}
# \hline
# 属落比 & 度 7 & 分 7 质 & 质商比 & 跏 $f$ & 分 子 \\
# \hline
# 1 & $\mathrm{H}^{+}$ & $\mathrm{H}_{2}$ & 26 & $\mathrm{C}_{2} \mathrm{H}_{\mathrm{C}^{*}}, \mathrm{CN}^{-}$ & $\mathrm{C}_{2} \mathrm{H}_{4}, \mathrm{C}_{2} \mathrm{H}_{3} \mathrm{O}, \mathrm{CNH}$ \\
# \hline
# 2 & $\mathrm{H}_{2}{ }^{*}$ & $\mathrm{H}_{3}$ & 27 & $\mathrm{C}_{2} \mathrm{H}_{3}{ }^{+}$, $\mathrm{CNH}^{+}$ & $\mathrm{C}_{2} \mathrm{H}_{4}, \mathrm{C}_{2} \mathrm{H}_{3} \mathrm{O}, \mathrm{CNH}$ \\
# \hline
# 4 & $\mathrm{He}^{+}$ & He a & 28 & $\mathrm{C}_{2} \mathrm{H}_{4}{ }^{+} . \mathrm{CO}^{\circ} \cdot \mathrm{N}_{2}$. & $\mathrm{C}_{2}$ H. $\mathrm{CO}_{2}, \mathrm{OB}_{2}, \mathrm{~N}_{2}$ \\
# \hline
# 8 & $0^{\circ}$. & o & 29 & \includegraphics[max width=\textwidth]{2024_09_13_8a2ddce69efcfc4d9ac9g-4(2)}
#  & CO.C2 $\mathrm{C}_{2} \mathrm{H}_{4} \mathrm{O}, \mathrm{C}_{2} \mathrm{H}_{4} . \mathrm{N}_{2}$ \\
# \hline
# 10 & 4 Hec & $2 \mathrm{a}^{\mathrm{Ne}}$ & 30 & $\mathrm{C}_{2} \mathrm{H}_{4}$ & $\mathrm{C}_{2} \mathrm{H}_{4}, \mathrm{C}_{2} \mathrm{H}_{4} \mathrm{O}$ \\
# \hline
# 11 & "Pe". & ${ }^{2} \mathrm{Ni}_{\mathrm{Ne}}$ & 3 & सb3 $^{\circ}$ & $\mathrm{C}_{2} \mathrm{H}_{4} \mathrm{O}$ \\
# \hline
# 12 & c* & $\mathrm{CH}_{4}, \mathrm{C}_{3} \mathrm{H}_{2}, \mathrm{CO}_{2}, \mathrm{CO}_{3}$ & 32 & $0^{\circ} \cdot \mathrm{s}^{\circ}$ & $\mathrm{O}_{2}, \mathrm{SO}_{2}, \mathrm{H}_{2} \mathrm{~S}$ \\
# \hline
# 13 & ${ }^{4} \mathrm{CO} . \mathrm{CH}$ & ${ }^{4} \mathrm{C}, \mathrm{CH}_{4}, \mathrm{C}_{2} \mathrm{H}_{4}$ & 33 & HS & $\mathrm{H}_{2} \mathrm{~S}$ \\
# \hline
# 14 & $\mathrm{~N}^{*} . \mathrm{CH}^{\circ} . \mathrm{CO}{ }^{\circ}$ & $\mathrm{N}_{2}, \mathrm{NH}_{3}, \mathrm{CH}_{4}, \mathrm{C}_{2} \mathrm{H}_{4} . \mathrm{CO}$ & 4 & H. ${ }^{\circ}$ & $\mathrm{H}_{2} \mathrm{~S}$ \\
# \hline
# 15 & $\mathrm{NH}^{\circ}, \mathrm{CH}_{3}{ }^{*}$ & $\mathrm{NH}_{3}, \mathrm{CH}_{4}$ & 35 & *O. & HC. $\mathrm{C}_{2} \mathrm{HCC}_{3}$ \\
# \hline
# 16 & $0^{\circ}, \mathrm{CH}_{4}{ }^{\circ}, \mathrm{NH}_{2}$, & $\mathrm{H}_{2} \mathrm{O}, \mathrm{CO}^{2}, \mathrm{CO}_{3}, \mathrm{O}_{2}, \mathrm{CH}_{4}, \mathrm{NH}_{4}$ & 36 & \includegraphics[max width=\textwidth]{2024_09_13_8a2ddce69efcfc4d9ac9g-4}
#  & $\mathrm{HO}, \mathrm{CHC}^{3}$ \\
# \hline
# 17 & $\mathrm{OH}^{+}, \mathrm{NH}^{*}$, & $\mathrm{H}_{2} \mathrm{O}, \mathrm{NH}_{3}$ & 37 & \includegraphics[max width=\textwidth]{2024_09_13_8a2ddce69efcfc4d9ac9g-4(3)}
#  & \includegraphics[max width=\textwidth]{2024_09_13_8a2ddce69efcfc4d9ac9g-4(4)}
#  \\
# \hline
# 18 & $\mathrm{H}_{3} \mathrm{O}^{\circ}$ & $\mathrm{H}_{3} \mathrm{O}$ & 38 & $\mathrm{H}^{\prime \prime} \mathrm{Cl}^{\circ}, \mathrm{C}_{1} \mathrm{H}^{*}$ & $\mathrm{HC}^{2}, \mathrm{C}_{2} \mathrm{HC}_{2}, \mathrm{C}_{3} \mathrm{H}_{2}$ \\
# \hline
# 19 & $\mathrm{~F}^{*}$ & $F_{2}$ & 39 & C, $\mathrm{H}_{3}{ }^{+}$ & $\mathrm{C}_{3} \mathrm{H}_{4}, \mathrm{C}_{3} \mathrm{H}_{4}$ \\
# \hline
# 20 & \includegraphics[max width=\textwidth]{2024_09_13_8a2ddce69efcfc4d9ac9g-4(1)}
#  & ${ }^{2} \mathrm{~N}_{\mathrm{Ne}}$. As & 40 & Ar ${ }^{*} \mathrm{CH}^{\circ}$ & $\mathrm{C}_{3} \mathrm{C}_{6}$. $\mathrm{Cod}_{4}$ \\
# \hline
# 22 & ${ }^{2} \mathrm{Ne}$, $\mathrm{CO}_{2}$, & ${ }^{2} \mathrm{Ne}, \mathrm{CO}_{3}$ & 4 & As, Cati & $\mathrm{As}^{\text {a }} \mathrm{C}_{3} \mathrm{H}_{4}$ \\
# \hline
# 24 & $\mathrm{C}_{2}{ }^{*}$ & $\mathrm{C}_{2} \mathrm{H}_{4}$ & 4 & $\mathrm{CH}_{3}{ }^{\circ}$ & $\mathrm{C}_{3} \mathrm{H}_{4}$.解 \\
# \hline
# 25 & $\mathrm{C}_{2} \mathrm{H}^{\text {- }}$ & $\mathrm{C}_{2} \mathrm{CH}_{4} \mathrm{C}_{2} \mathrm{C}_{4} \mathrm{O}$ & 42 & $\mathrm{C}_{3} \mathrm{CH}_{4}$ & $\mathrm{C}_{3} \mathrm{H}_{4} . \mathrm{C}_{3} \mathrm{H}_{20}$ \\
# \hline
#  &  &  &  & \includegraphics[max width=\textwidth]{2024_09_13_8a2ddce69efcfc4d9ac9g-4(5)}
#  & $\mathrm{CH}_{4} \mathrm{H}_{10}$. 神 \\
# \hline
# \end{tabular}
# \end{center}
#
# \begin{center}
# \includegraphics[max width=\textwidth]{2024_09_13_8a2ddce69efcfc4d9ac9g-4(6)}
# \end{center}
#
#
# \end{document}
# ------------------------------
# Splitting into chunks ...
# Splitting successfully, the chunks are:
# ==============================
# The #1 chunks:
# --------------------
# % This LaTeX document needs to be compiled with XeLaTeX.
# \documentclass[10pt]{article}
# \usepackage[utf8]{inputenc}
# \usepackage{ucharclasses}
# \usepackage{amsmath}
# \usepackage{amsfonts}
# \usepackage{amssymb}
# \usepackage[version=4]{mhchem}
# \usepackage{stmaryrd}
# \usepackage{graphicx}
# \usepackage[export]{adjustbox}
# \graphicspath{ {./images/} }
# \usepackage{multirow}
# \usepackage[fallback]{xeCJK}
# \usepackage{polyglossia}
# \usepackage{fontspec}
# \setCJKmainfont{Noto Serif CJK SC}
#
# \setmainlanguage{english}
# \setotherlanguages{hindi}
# \newfontfamily\hindifont{Noto Serif Devanagari}
# \newfontfamily\lgcfont{CMU Serif}
# \setDefaultTransitions{\lgcfont}{}
# \setTransitionsFor{Hindi}{\hindifont}{\lgcfont}
#
# \title{使用离子流计算分压力的方法: }
#
# \author{}
# \date{}
#
#
# \begin{document}
# \maketitle
# 实验内容:
#
# \begin{enumerate}
#   \item 使用法拉第筒收集缡子流，以分压力为纵坐标测三个谱
#   \item 将上达测得的一个谱转化成以离子流为纵坐标, 并用离子流求出残余气体 $\left(\mathrm{H}_{2}, \mathrm{He}^{2}, \mathrm{CH}_{4}, \mathrm{H}_{2} \mathrm{O}, \mathrm{N}_{2}, \mathrm{CO}, \mathrm{O}_{2}, \mathrm{Ar}\right.$ 和 $\left.\mathrm{CO}_{2}\right)$ 的分压, 再与以分压力为纵坐标的橧进行比较, 分析造成两者差距的原因 (残余气体分压的计算结果需要写进实验报告)。
# \end{enumerate}
#
#
# --------------------
# The #2 chunks:
# --------------------
# 在用残余气体分析仪(RGA) 分析真空系统中的残余气体成分时，为了计算出主要的几种残余气体的分压，需要分析清楚所观察到的谱峰与残余气体之间的关系。由于残余气体是混合气体，在谱图中，除了有相应于一次电离分子的主峰外, 还存在着一些副峰, 这些副峰主要来源于气体电离时形成的碎片离子、多电荷离子及同位素杂质。某一种组分气体电离所得到的各个峰的丰度仅取决于该组分气体的碎片图形，而与所分析的混合气体中存在的其它组分气体无关。在分析不同组分气体对谱图中某一个峰的贡献时可以采用线性叠加的方法, 在此基础上可以求得组分气体的分压。
#
# \section*{1. 峰与残余气体分压的关系}
# 对于 RGA 扫描出的某个峰 $a$ 来说. 其离子流的值 $I_{a}$ 可能是多种组分气体贡献的迭加, 即:
#
#
# \begin{equation*}
# I_{a}=\sum_{i} I_{i a} \tag{1}
# \end{equation*}
#
#
# 式中， $I_{I a}$ 是第 $i$ 种气体的全离子流 $I$ 中被 RGA 检测到的质荷比为 $a$ 的离子流的值, $I_{w}$ 与 $I$ 的关系是:
#
#
# \begin{equation*}
# I_{i a}=T_{a} \bullet F_{i a} \bullet I_{i} \tag{2}
# \end{equation*}
#
#
# 式中 $F_{i a}$ 是第 $i$ 中气体的全离子流中质荷比为 $a$ 的离子流所占的丰度, $T_{a}$ 是 RGA 对质何比为 $a$ 的离子流的传输几率。假设第 $i$ 种气体的分压为 $p_{1}, \mathrm{RGA}$ 住使用法拉第筒的情况下， $l_{1}$ 对 $p$ 的灵敏度（也就是第 $i$ 种气体的灵敏度）为 $s_{1}$ ，那么, $p$ ，和 $I$ ，有以下关系：
#
#
# \begin{equation*}
# I_{i}=s_{i} \cdot p_{i} \tag{3}
# \end{equation*}
#
#
# 不同气体之所以会有不同的灵敏度，主要是因为它们的电离茷面不同。杲种气体(设为第 $i$ 种气(体)相对于钻气气的相对电离截面 $\sigma_{1}$ 一般是稳定的常数, 那么,
#
# \begin{center}
# \includegraphics[max width=\textwidth]{2024_09_13_8a2ddce69efcfc4d9ac9g-2}
# \end{center}
#
#
# \begin{equation*}
# s_{1}=\sigma_{1} \bullet s_{N_{2}} \tag{4}
# \end{equation*}
#
#
#
# --------------------
# The #3 chunks:
# --------------------
# 通常RGA的说明书里不会给出每种气体的全离子流对该气体的灵敏度，而是给出在法拉第简的情况下 $\left.1^{14} \mathrm{~N}_{2}\right]^{+}$(质荷比为 28 ) 离了流对氮气的灵敏度 $s$ 作为 RGA的标称灵敏度。注意， $s$ 并不是氮气的灵敏度！
#
# 得气的灵敏度 $s_{\mathrm{V}}$, 与RGA的标称灵敏度 $s$ 有如下关系:
#
#
# \begin{equation*}
# s=T_{28} \bullet F_{\left.N_{2} \mid 28\right]} \bullet s_{N_{2}} \tag{5}
# \end{equation*}
#
#
# 式中 $F_{\mathrm{N},[28]}$ 是氮气的全离子流中 $\left[{ }^{14} \mathrm{~N}_{2}\right]^{+}$的丰度， $T_{28}$ 是质谱计对质荷比为 28 的离子流的传输几率。
#
# 由式（1）－（5）可以得出RGA扫描出的某个峰 $a$ 与对它有贡献的各残余气体分压的关系为:
#
#
# \begin{equation*}
# I_{a}=\sum_{1} \frac{p_{1} \bullet s \bullet \sigma_{1} \bullet T_{a} \bullet F_{\text {Ia }}}{T_{28} \bullet F_{N_{2}[28]}} \tag{6}
# \end{equation*}
#
#
# 注意到某些峰只来源于单一气体, 比如[2]峰只来源于 $\mathrm{H}_{2}$, [4]峰只来源于 He ,那么对于这样的峰,式(6)中的求和符号可以去掉, 根据 $I_{2}$ 可以直接计算 $p_{H_{2}}$, 根据 $I_{4}$可以直接计算 $p_{\text {Hic }}$ 。如果某个峰不是来源于单一气体，比如[28]可能来自 $\mathrm{N}_{2}$ 和 CO , 那么可以选择与 $\mathrm{N}_{2}$ 和 CO 相关的副峰[14]来参与计算, 通过解方程组求得 $\mathrm{N}_{2}$ 和 CO 的分压。
#
# \section*{2. 系数的确定}
# 在超高真空系统中,残余气体的主要包括 $\mathrm{H}_{2}, \mathrm{He}^{2}, \mathrm{CH}_{4}, \mathrm{H}_{2} \mathrm{O}, \mathrm{N}_{2}, \mathrm{CO}, \mathrm{O}_{2}, \mathrm{Ar}$ 和 $\mathrm{CO}_{2}$这些气体，它们的离子的质荷比都在 50 以内。
#
# 常见气体的相对电离截面 $\sigma_{i}$ 可以从下表中计算得出。
#
# \includegraphics[max width=\textwidth, center]{2024_09_13_8a2ddce69efcfc4d9ac9g-3(1)}\\
# $T_{\rho} / T_{28}$ 是质哬比为 $a$ 的离子流的相对传输几率 (相对 $\left[^{[4} \mathrm{N}_{2}\right]^{+}$), 通常有如下关系:
#
#
#
# --------------------
# The #4 chunks:
# --------------------
# \begin{equation*}
# \frac{T_{a}}{T_{28}}=\frac{28}{a} \tag{7}
# \end{equation*}
#
#
# $F_{i u}$ 和 $F_{N, 128]}$ 可以查气体的碎片图形表. 有衣中的相对丰度（主峰为 $100 \%$ ）米计算丰度如表2。
#
# 表2 常见残余气体果暨床不比䁖的丰度
#
# \begin{center}
# \begin{tabular}{|c|c|c|}
# \hline
# ${ }^{2}$ (14 & \includegraphics[max width=\textwidth]{2024_09_13_8a2ddce69efcfc4d9ac9g-3}
#  & 112 \\
# \hline
# \multirow{2}{*}{$\mathrm{N}_{2}$} & 28 & 0.94366 \\
# \hline
#  & 14 & 0. 0490705 \\
# \hline
# $\mathrm{H}_{2}$ & 2 & 0.97943 \\
# \hline
# He & 4 & 1 \\
# \hline
# \multirow{2}{*}{$\mathrm{CH}_{4}$} & 15 & 0. 40168 \\
# \hline
#  & 14 & 0.0747314 \\
# \hline
# $\mathrm{H}_{2} \mathrm{O}$ & 18 & $0.76 \times 05$ \\
# \hline
# \multirow{2}{*}{co} & 28 & 0.92166 \\
# \hline
#  & 14 & 0. 0064516 \\
# \hline
# $\mathrm{O}_{2}$ & 32 & 0.92098 \\
# \hline
# Ar & 40 & 0. $8 \times 1 \times 3$ \\
# \hline
# \multirow{2}{*}{$\mathrm{CO}_{2}$} & 44 & 0.76570 \\
# \hline
#  & 28 & 0.068913 \\
# \hline
# \end{tabular}
# \end{center}
#
# 本实验中所用的RGA的标称灵敏度 $s=1.36 \times 10^{-1}$
#
# \section*{3. 分压的计算}
# 要求：选取质荷比分别为 $2,4,15,18,32,40,44$ 的 7 个峰（可以认为这些峰来自于单一气体）的离子流值来分别计算 $\mathrm{H}_{2}, \mathrm{He}^{-}, \mathrm{CH}_{4}, \mathrm{H}_{2} \mathrm{O}, \mathrm{O}_{2}, \mathrm{Ar}$ 和 $\mathrm{CO}_{2}$ 的分
#
# \section*{压。选取荷质比为 14 和 28 的峰的离子流来计算 $\mathrm{N}_{2}$ 和 CO 分压（需要列方程组求解)。}
# \section*{4. 附表(真空设计手册第十二章 第七节]}
# 由下面的表12-9至表12-11可以求出某种气体碎裂后, 不同质荷比的离子的丰度。以 N 2 的 $\left[{ }^{14} \mathrm{~N}_{2}\right]^{+}$的丰度为例:
#
#
# --------------------
# ==============================
# Using LLM correcting ...
# Correction successfully, the modified content is:
# ------------------------------
# latex
# % This LaTeX document needs to be compiled with XeLaTeX.
# \documentclass[10pt]{article}
# \usepackage[utf8]{inputenc}
# \usepackage{ucharclasses}
# \usepackage{amsmath}
# \usepackage{amsfonts}
# \usepackage{amssymb}
# \usepackage[version=4]{mhchem}
# \usepackage{stmaryrd}
# \usepackage{graphicx}
# \usepackage[export]{adjustbox}
# \graphicspath{ {./images/} }
# \usepackage{multirow}
# \usepackage[fallback]{xeCJK}
# \usepackage{polyglossia}
# \usepackage{fontspec}
# \setCJKmainfont{Noto Serif CJK SC}
#
# \setmainlanguage{english}
# \setotherlanguages{hindi}
# \newfontfamily\hindifont{Noto Serif Devanagari}
# \newfontfamily\lgcfont{CMU Serif}
# \setDefaultTransitions{\lgcfont}{}
# \setTransitionsFor{Hindi}{\hindifont}{\lgcfont}
#
# \title{使用离子流计算分压力的方法}
#
# \author{}
# \date{}
#
# \begin{document}
# \maketitle
# 实验内容:
#
# \begin{enumerate}
#   \item 使用法拉第筒收集离子流，以分压力为纵坐标测三个谱
#   \item 将上述测得的一个谱转化成以离子流为纵坐标，并用离子流求出残余气体 $\left(\mathrm{H}_{2}, \mathrm{He}, \mathrm{CH}_{4}, \mathrm{H}_{2} \mathrm{O}, \mathrm{N}_{2}, \mathrm{CO}, \mathrm{O}_{2}, \mathrm{Ar}\right.$ 和 $\left.\mathrm{CO}_{2}\right)$ 的分压，再与以分压力为纵坐标的谱进行比较，分析造成两者差距的原因（残余气体分压的计算结果需要写进实验报告）。
# \end{enumerate}
#
# \end{document}
# latex
# \section*{1. 峰与残余气体分压的关系}
# 对于 RGA 扫描出的某个峰 $a$ 来说，其离子流的值 $I_{a}$ 可能是多种组分气体贡献的叠加，即：
#
# \begin{equation}
# I_{a} = \sum_{i} I_{i a} \label{eq:1}
# \end{equation}
#
# 式中，$I_{i a}$ 是第 $i$ 种气体的全离子流 $I$ 中被 RGA 检测到的质荷比为 $a$ 的离子流的值，$I_{i a}$ 与 $I$ 的关系是：
#
# \begin{equation}
# I_{i a} = T_{a} \cdot F_{i a} \cdot I_{i} \label{eq:2}
# \end{equation}
#
# 式中 $F_{i a}$ 是第 $i$ 种气体的全离子流中质荷比为 $a$ 的离子流所占的丰度，$T_{a}$ 是 RGA 对质荷比为 $a$ 的离子流的传输几率。假设第 $i$ 种气体的分压为 $p_{i}$，RGA 在使用法拉第筒的情况下，$I_{i}$ 对 $p_{i}$ 的灵敏度（也就是第 $i$ 种气体的灵敏度）为 $s_{i}$，那么，$p_{i}$ 和 $I_{i}$ 有以下关系：
#
# \begin{equation}
# I_{i} = s_{i} \cdot p_{i} \label{eq:3}
# \end{equation}
#
# 不同气体之所以会有不同的灵敏度，主要是因为它们的电离截面不同。某种气体（设为第 $i$ 种气体）相对于氮气的相对电离截面 $\sigma_{i}$ 一般是稳定的常数，那么：
#
# \begin{equation}
# s_{i} = \sigma_{i} \cdot s_{N_{2}} \label{eq:4}
# \end{equation}
#
# \begin{center}
# \includegraphics[max width=\textwidth]{2024_09_13_8a2ddce69efcfc4d9ac9g-2}
# \end{center}
# latex
# 通常RGA的说明书里不会给出每种气体的全离子流对该气体的灵敏度，而是给出在法拉第简的情况下 $\left[{}^{14} \mathrm{N}_{2}\right]^{+}$（质荷比为 28）离子流对氮气的灵敏度 $s$ 作为 RGA的标称灵敏度。注意，$s$ 并不是氮气的灵敏度！
#
# 氮气的灵敏度 $s_{\mathrm{N}_{2}}$，与RGA的标称灵敏度 $s$ 有如下关系：
#
# \begin{equation*}
# s = T_{28} \cdot F_{\left[{}^{14} \mathrm{N}_{2}\right]^{+}} \cdot s_{\mathrm{N}_{2}} \tag{5}
# \end{equation*}
#
# 式中 $F_{\left[{}^{14} \mathrm{N}_{2}\right]^{+}}$ 是氮气的全离子流中 $\left[{}^{14} \mathrm{N}_{2}\right]^{+}$ 的丰度，$T_{28}$ 是质谱计对质荷比为 28 的离子流的传输几率。
#
# 由式（1）－（5）可以得出RGA扫描出的某个峰 $a$ 与对它有贡献的各残余气体分压的关系为：
#
# \begin{equation*}
# I_{a} = \sum_{i} \frac{p_{i} \cdot s \cdot \sigma_{i} \cdot T_{a} \cdot F_{\left[a\right]^{+}}}{T_{28} \cdot F_{\left[{}^{14} \mathrm{N}_{2}\right]^{+}}} \tag{6}
# \end{equation*}
#
# 注意到某些峰只来源于单一气体，比如[2]峰只来源于 $\mathrm{H}_{2}$，[4]峰只来源于 $\mathrm{He}$，那么对于这样的峰，式(6)中的求和符号可以去掉，根据 $I_{2}$ 可以直接计算 $p_{\mathrm{H}_{2}}$，根据 $I_{4}$ 可以直接计算 $p_{\mathrm{He}}$。如果某个峰不是来源于单一气体，比如[28]可能来自 $\mathrm{N}_{2}$ 和 $\mathrm{CO}$，那么可以选择与 $\mathrm{N}_{2}$ 和 $\mathrm{CO}$ 相关的副峰[14]来参与计算，通过解方程组求得 $\mathrm{N}_{2}$ 和 $\mathrm{CO}$ 的分压。
#
# \section*{2. 系数的确定}
# 在超高真空系统中，残余气体的主要包括 $\mathrm{H}_{2}$，$\mathrm{He}$，$\mathrm{CH}_{4}$，$\mathrm{H}_{2}\mathrm{O}$，$\mathrm{N}_{2}$，$\mathrm{CO}$，$\mathrm{O}_{2}$，$\mathrm{Ar}$ 和 $\mathrm{CO}_{2}$ 这些气体，它们的离子的质荷比都在 50 以内。
#
# 常见气体的相对电离截面 $\sigma_{i}$ 可以从下表中计算得出。
#
# \includegraphics[max width=\textwidth, center]{2024_09_13_8a2ddce69efcfc4d9ac9g-3(1)}\\
# $T_{a} / T_{28}$ 是质荷比为 $a$ 的离子流的相对传输几率（相对 $\left[{}^{14} \mathrm{N}_{2}\right]^{+}$），通常有如下关系：
#
# \begin{equation*}
# T_{a} = \frac{T_{a}}{T_{28}}
# \end{equation*}
# latex
# \begin{equation*}
# \frac{T_{a}}{T_{28}}=\frac{28}{a} \tag{7}
# \end{equation*}
#
# $F_{iu}$ 和 $F_{N, 128}$ 可以查气体的碎片图形表。有衣中的相对丰度（主峰为 $100 \%$）来计算丰度如表2。
#
# 表2 常见残余气体及其相对丰度的丰度
#
# \begin{center}
# \begin{tabular}{|c|c|c|}
# \hline
# 质荷比 & 相对丰度 & 备注 \\
# \hline
# ${}^{14}$N$_{2}$ & 28 & 0.94366 \\
# \hline
#  & 14 & 0.0490705 \\
# \hline
# H$_{2}$ & 2 & 0.97943 \\
# \hline
# He & 4 & 1 \\
# \hline
# CH$_{4}$ & 15 & 0.40168 \\
# \hline
#  & 14 & 0.0747314 \\
# \hline
# H$_{2}$O & 18 & 0.76 \times 10^{5} \\
# \hline
# CO & 28 & 0.92166 \\
# \hline
#  & 14 & 0.0064516 \\
# \hline
# O$_{2}$ & 32 & 0.92098 \\
# \hline
# Ar & 40 & 0.8 \times 10^{3} \\
# \hline
# CO$_{2}$ & 44 & 0.76570 \\
# \hline
#  & 28 & 0.068913 \\
# \hline
# \end{tabular}
# \end{center}
#
# 本实验中所用的RGA的标称灵敏度 $s=1.36 \times 10^{-1}$
#
# \section*{3. 分压的计算}
# 要求：选取质荷比分别为 $2,4,15,18,32,40,44$ 的 7 个峰（可以认为这些峰来自于单一气体）的离子流值来分别计算 $\mathrm{H}_{2}, \mathrm{He}, \mathrm{CH}_{4}, \mathrm{H}_{2} \mathrm{O}, \mathrm{O}_{2}, \mathrm{Ar}$ 和 $\mathrm{CO}_{2}$ 的分压。选取荷质比为 14 和 28 的峰的离子流来计算 $\mathrm{N}_{2}$ 和 CO 分压（需要列方程组求解）。
#
# \section*{4. 附表(真空设计手册第十二章 第七节)}
# 由下面的表12-9至表12-11可以求出某种气体碎裂后, 不同质荷比的离子的丰度。以 N$_{2}$ 的 $\left[{}^{14}\mathrm{N}_{2}\right]^{+}$的丰度为例:
#
# ------------------------------
